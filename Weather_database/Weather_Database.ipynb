# %%
# Import the dependencies
import json
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time
import pandas as pd

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"

# %%
# This was a test cell to be sure the code could process a city correctly

#city_data = []
#city = cities[0]
#city_url = url + "q=" + city.replace(" ","+") + "&appid=" + weather_api_key
#city_weather = requests.get(city_url).json()
#city_lat = city_weather["coord"]["lat"]
#city_lng = city_weather["coord"]["lon"]
#city_max_temp = city_weather["main"]["temp_max"]
#city_humidity = city_weather["main"]["humidity"]
#city_clouds = city_weather["clouds"]["all"]
#city_wind = city_weather["wind"]["speed"]
#city_country = city_weather["sys"]["country"]
#city_description = city_weather["weather"][0]["description"]
#city_data.append({ "City": city.title(),
#                   "Country": city_country,
 #                   "Lat": city_lat,
  #                  "Lng": city_lng,
   #                 "Max Temp": city_max_temp,
    #                "Humidity": city_humidity,
     #               "Cloudiness": city_clouds,
      #              "Wind Speed": city_wind,
       #             "Current Description": city_description})
                          
#print (city_data)

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(2)

    # Create endpoint URL with each city.
    city_url = url + "q=" + city.replace(" ","+") + "&appid=" + weather_api_key +"&units=imperial"

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_data.append({ "City": city.title(),
                           "Country": city_country,
                           "Lat": city_lat,
                           "Lng": city_lng,
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | muana
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | kwinana
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | trapani
# Processing Record 8 of Set 1 | yumen
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | saint-pierre
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | port hardy
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | nova vicosa
# Processing Record 16 of Set 1 | saint-augustin
# Processing Record 17 of Set 1 | angoche
# Processing Record 18 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | bang saphan
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | staryy nadym
# Processing Record 25 of Set 1 | markova
# Processing Record 26 of Set 1 | kununurra
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | waddan
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | neiafu
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | egvekinot
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | vaovai
# City not found. Skipping...
# Processing Record 36 of Set 1 | mae ramat
# Processing Record 37 of Set 1 | san francisco
# Processing Record 38 of Set 1 | san cristobal
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | guerrero negro
# Processing Record 41 of Set 1 | lagarto
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | constitucion
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | lata
# Processing Record 46 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 1 | petrovsk
# Processing Record 48 of Set 1 | tandil
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | versalles
# Processing Record 1 of Set 2 | nanakuli
# Processing Record 2 of Set 2 | micheweni
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | puerto escondido
# Processing Record 6 of Set 2 | byron bay
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | bukama
# Processing Record 9 of Set 2 | ketchikan
# Processing Record 10 of Set 2 | brae
# Processing Record 11 of Set 2 | tuatapere
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | nizwa
# Processing Record 15 of Set 2 | mount gambier
# Processing Record 16 of Set 2 | presidencia roque saenz pena
# Processing Record 17 of Set 2 | buala
# Processing Record 18 of Set 2 | fenoarivo
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | melfi
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 23 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | gravdal
# Processing Record 28 of Set 2 | anagni
# Processing Record 29 of Set 2 | tessalit
# Processing Record 30 of Set 2 | bandar-e lengeh
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | usevya
# Processing Record 34 of Set 2 | wajir
# Processing Record 35 of Set 2 | yeniseysk
# Processing Record 36 of Set 2 | saint-joseph
# Processing Record 37 of Set 2 | adrar
# Processing Record 38 of Set 2 | pimenta bueno
# Processing Record 39 of Set 2 | araouane
# Processing Record 40 of Set 2 | humboldt
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | alibag
# Processing Record 44 of Set 2 | tocache
# Processing Record 45 of Set 2 | hongan
# City not found. Skipping...
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | port blair
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | muros
# Processing Record 1 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | mesyagutovo
# Processing Record 4 of Set 3 | pangai
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | abha
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | kawalu
# Processing Record 10 of Set 3 | vaini
# Processing Record 11 of Set 3 | cap malheureux
# Processing Record 12 of Set 3 | nhulunbuy
# Processing Record 13 of Set 3 | lavrentiya
# Processing Record 14 of Set 3 | linares
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | bandarbeyla
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | moerai
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | labuhan
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | saint george
# Processing Record 24 of Set 3 | samarai
# Processing Record 25 of Set 3 | dunedin
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | savona
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | gweta
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | tual
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | carutapera
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | ponerihouen
# Processing Record 38 of Set 3 | ca mau
# Processing Record 39 of Set 3 | saldanha
# Processing Record 40 of Set 3 | cedar city
# Processing Record 41 of Set 3 | inhambane
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | upington
# Processing Record 44 of Set 3 | ostrovnoy
# Processing Record 45 of Set 3 | balakhninskiy
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | karratha
# Processing Record 48 of Set 3 | kendari
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | pisco
# Processing Record 1 of Set 4 | taltal
# Processing Record 2 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 4 | aguilas
# Processing Record 4 of Set 4 | yulara
# Processing Record 5 of Set 4 | yangambi
# Processing Record 6 of Set 4 | calafell
# Processing Record 7 of Set 4 | el dorado
# Processing Record 8 of Set 4 | safaga
# Processing Record 9 of Set 4 | itarema
# Processing Record 10 of Set 4 | peterhead
# Processing Record 11 of Set 4 | new port richey
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | turukhansk
# Processing Record 14 of Set 4 | perth
# Processing Record 15 of Set 4 | grindavik
# Processing Record 16 of Set 4 | touros
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | kautokeino
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | eyl
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | les escoumins
# Processing Record 24 of Set 4 | mananjary
# Processing Record 25 of Set 4 | hami
# Processing Record 26 of Set 4 | ulcinj
# Processing Record 27 of Set 4 | sayyan
# Processing Record 28 of Set 4 | biak
# Processing Record 29 of Set 4 | rorvik
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | alyangula
# Processing Record 32 of Set 4 | matay
# Processing Record 33 of Set 4 | salym
# Processing Record 34 of Set 4 | somerset
# Processing Record 35 of Set 4 | asyut
# Processing Record 36 of Set 4 | cartagena del chaira
# Processing Record 37 of Set 4 | sebezh
# Processing Record 38 of Set 4 | dingle
# Processing Record 39 of Set 4 | napasar
# Processing Record 40 of Set 4 | san quintin
# Processing Record 41 of Set 4 | tripoli
# Processing Record 42 of Set 4 | new norfolk
# Processing Record 43 of Set 4 | keetmanshoop
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | launceston
# Processing Record 46 of Set 4 | kollam
# Processing Record 47 of Set 4 | huilong
# Processing Record 48 of Set 4 | fortuna
# Processing Record 49 of Set 4 | antofagasta
# Processing Record 50 of Set 4 | batagay-alyta
# Processing Record 1 of Set 5 | ust-maya
# Processing Record 2 of Set 5 | vilyuysk
# Processing Record 3 of Set 5 | noumea
# Processing Record 4 of Set 5 | husavik
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | faanui
# Processing Record 7 of Set 5 | port-gentil
# Processing Record 8 of Set 5 | makurdi
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | bethel
# Processing Record 11 of Set 5 | yeltsovka
# City not found. Skipping...
# Processing Record 12 of Set 5 | itaperucu
# Processing Record 13 of Set 5 | mount isa
# Processing Record 14 of Set 5 | salinopolis
# Processing Record 15 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 5 | talnakh
# Processing Record 17 of Set 5 | new smyrna beach
# Processing Record 18 of Set 5 | vila
# Processing Record 19 of Set 5 | koumac
# Processing Record 20 of Set 5 | zhigansk
# Processing Record 21 of Set 5 | mbulu
# Processing Record 22 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 5 | half moon bay
# Processing Record 24 of Set 5 | krasnotorka
# Processing Record 25 of Set 5 | coquimbo
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | abu dhabi
# Processing Record 28 of Set 5 | pangoa
# Processing Record 29 of Set 5 | hasaki
# Processing Record 30 of Set 5 | deputatskiy
# Processing Record 31 of Set 5 | sabirabad
# Processing Record 32 of Set 5 | praya
# Processing Record 33 of Set 5 | dhidhdhoo
# Processing Record 34 of Set 5 | tasiilaq
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | kaeo
# Processing Record 37 of Set 5 | scarborough
# Processing Record 38 of Set 5 | vyartsilya
# Processing Record 39 of Set 5 | college
# Processing Record 40 of Set 5 | tucuma
# Processing Record 41 of Set 5 | san pedro de ycuamandiyu
# Processing Record 42 of Set 5 | umm lajj
# Processing Record 43 of Set 5 | odemira
# Processing Record 44 of Set 5 | los llanos de aridane
# Processing Record 45 of Set 5 | georgetown
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | santa marta
# Processing Record 48 of Set 5 | waitati
# Processing Record 49 of Set 5 | butaritari
# Processing Record 50 of Set 5 | vila velha
# Processing Record 1 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 2 of Set 6 | shingu
# Processing Record 3 of Set 6 | provideniya
# Processing Record 4 of Set 6 | cherskiy
# Processing Record 5 of Set 6 | kaitangata
# Processing Record 6 of Set 6 | krasnousolskiy
# City not found. Skipping...
# Processing Record 7 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 6 | boguchany
# Processing Record 9 of Set 6 | assiniboia
# Processing Record 10 of Set 6 | elizabeth city
# Processing Record 11 of Set 6 | houston
# Processing Record 12 of Set 6 | natal
# Processing Record 13 of Set 6 | poya
# Processing Record 14 of Set 6 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 15 of Set 6 | dawlatabad
# Processing Record 16 of Set 6 | khovu-aksy
# Processing Record 17 of Set 6 | sao felix do xingu
# Processing Record 18 of Set 6 | novobirilyussy
# Processing Record 19 of Set 6 | san angelo
# Processing Record 20 of Set 6 | khanpur
# Processing Record 21 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 6 | djambala
# Processing Record 23 of Set 6 | torbay
# Processing Record 24 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 6 | alice springs
# Processing Record 26 of Set 6 | kifri
# Processing Record 27 of Set 6 | la palma
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | campbeltown
# Processing Record 30 of Set 6 | yefimovskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | sakaiminato
# Processing Record 32 of Set 6 | vestmannaeyjar
# Processing Record 33 of Set 6 | whitehorse
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | ribeira grande
# Processing Record 36 of Set 6 | kishtwar
# Processing Record 37 of Set 6 | pestravka
# Processing Record 38 of Set 6 | fort nelson
# Processing Record 39 of Set 6 | leningradskiy
# Processing Record 40 of Set 6 | teknaf
# Processing Record 41 of Set 6 | port lincoln
# Processing Record 42 of Set 6 | yanliang
# Processing Record 43 of Set 6 | namatanai
# Processing Record 44 of Set 6 | akureyri
# Processing Record 45 of Set 6 | menongue
# Processing Record 46 of Set 6 | hofn
# Processing Record 47 of Set 6 | cordoba
# Processing Record 48 of Set 6 | kant
# Processing Record 49 of Set 6 | pemberton
# Processing Record 50 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 7 | gazojak
# Processing Record 2 of Set 7 | chaihe
# Processing Record 3 of Set 7 | mogzon
# Processing Record 4 of Set 7 | panzhihua
# Processing Record 5 of Set 7 | axim
# Processing Record 6 of Set 7 | comodoro rivadavia
# Processing Record 7 of Set 7 | bijie
# Processing Record 8 of Set 7 | nisia floresta
# Processing Record 9 of Set 7 | aksarka
# Processing Record 10 of Set 7 | dudinka
# Processing Record 11 of Set 7 | at-bashi
# Processing Record 12 of Set 7 | vostok
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 | saint-philippe
# Processing Record 15 of Set 7 | surgut
# Processing Record 16 of Set 7 | vung tau
# Processing Record 17 of Set 7 | nanortalik
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | novikovo
# Processing Record 20 of Set 7 | phonhong
# Processing Record 21 of Set 7 | jishui
# Processing Record 22 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 7 | panaba
# Processing Record 24 of Set 7 | ust-nera
# Processing Record 25 of Set 7 | thinadhoo
# Processing Record 26 of Set 7 | purranque
# Processing Record 27 of Set 7 | calvia
# Processing Record 28 of Set 7 | antananarivo
# Processing Record 29 of Set 7 | serenje
# Processing Record 30 of Set 7 | churapcha
# Processing Record 31 of Set 7 | koungheul
# Processing Record 32 of Set 7 | la reforma
# Processing Record 33 of Set 7 | susanville
# Processing Record 34 of Set 7 | prince rupert
# Processing Record 35 of Set 7 | nome
# Processing Record 36 of Set 7 | tarakan
# Processing Record 37 of Set 7 | yagoua
# Processing Record 38 of Set 7 | carsamba
# Processing Record 39 of Set 7 | sur
# Processing Record 40 of Set 7 | la oroya
# Processing Record 41 of Set 7 | khangarh
# Processing Record 42 of Set 7 | corn island
# Processing Record 43 of Set 7 | balakhta
# Processing Record 44 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 7 | qui nhon
# Processing Record 46 of Set 7 | vargashi
# Processing Record 47 of Set 7 | necochea
# Processing Record 48 of Set 7 | chandler
# Processing Record 49 of Set 7 | kuito
# Processing Record 50 of Set 7 | atambua
# Processing Record 1 of Set 8 | mahe
# Processing Record 2 of Set 8 | camopi
# Processing Record 3 of Set 8 | voskresenskoye
# Processing Record 4 of Set 8 | cruzeiro do sul
# Processing Record 5 of Set 8 | guaiuba
# Processing Record 6 of Set 8 | hithadhoo
# Processing Record 7 of Set 8 | iqaluit
# Processing Record 8 of Set 8 | bereda
# Processing Record 9 of Set 8 | laguna
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | acapulco
# Processing Record 12 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 8 | pacific grove
# Processing Record 14 of Set 8 | san policarpo
# Processing Record 15 of Set 8 | lavumisa
# Processing Record 16 of Set 8 | stanghelle
# Processing Record 17 of Set 8 | licheng
# Processing Record 18 of Set 8 | lazaro cardenas
# Processing Record 19 of Set 8 | oktyabrskiy
# Processing Record 20 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 8 | lompoc
# Processing Record 22 of Set 8 | warkworth
# Processing Record 23 of Set 8 | goderich
# Processing Record 24 of Set 8 | la seyne-sur-mer
# Processing Record 25 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 8 | maua
# Processing Record 27 of Set 8 | kampene
# Processing Record 28 of Set 8 | shambu
# Processing Record 29 of Set 8 | flinders
# Processing Record 30 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 8 | airai
# Processing Record 32 of Set 8 | mercedes
# Processing Record 33 of Set 8 | abashiri
# Processing Record 34 of Set 8 | ville-marie
# Processing Record 35 of Set 8 | malacky
# Processing Record 36 of Set 8 | cubuk
# Processing Record 37 of Set 8 | victoria
# Processing Record 38 of Set 8 | taraz
# Processing Record 39 of Set 8 | monticello
# Processing Record 40 of Set 8 | evensk
# Processing Record 41 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 8 | qitaihe
# Processing Record 43 of Set 8 | roebourne
# Processing Record 44 of Set 8 | pathein
# Processing Record 45 of Set 8 | shangrao
# Processing Record 46 of Set 8 | komsomolskiy
# Processing Record 47 of Set 8 | khandyga
# Processing Record 48 of Set 8 | nantucket
# Processing Record 49 of Set 8 | yining
# Processing Record 50 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 9 | navirai
# Processing Record 2 of Set 9 | aklavik
# Processing Record 3 of Set 9 | male
# Processing Record 4 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 9 | grand gaube
# Processing Record 6 of Set 9 | lanzhou
# Processing Record 7 of Set 9 | garoua boulai
# Processing Record 8 of Set 9 | paamiut
# Processing Record 9 of Set 9 | richards bay
# Processing Record 10 of Set 9 | sao borja
# Processing Record 11 of Set 9 | ulaangom
# Processing Record 12 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 9 | nelson bay
# Processing Record 14 of Set 9 | bubaque
# Processing Record 15 of Set 9 | ixtapa
# Processing Record 16 of Set 9 | grand baie
# Processing Record 17 of Set 9 | gumushane
# City not found. Skipping...
# Processing Record 18 of Set 9 | turka
# Processing Record 19 of Set 9 | teahupoo
# Processing Record 20 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 9 | ilfracombe
# Processing Record 22 of Set 9 | teguise
# Processing Record 23 of Set 9 | alofi
# Processing Record 24 of Set 9 | sao joao da barra
# Processing Record 25 of Set 9 | chenghai
# Processing Record 26 of Set 9 | makakilo city
# Processing Record 27 of Set 9 | plovdiv
# Processing Record 28 of Set 9 | ouango
# Processing Record 29 of Set 9 | kondopoga
# Processing Record 30 of Set 9 | shestakovo
# Processing Record 31 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 9 | jaguariaiva
# Processing Record 33 of Set 9 | olinda
# Processing Record 34 of Set 9 | grand-santi
# Processing Record 35 of Set 9 | ust-ilimsk
# Processing Record 36 of Set 9 | jaciara
# Processing Record 37 of Set 9 | pangody
# Processing Record 38 of Set 9 | palana
# Processing Record 39 of Set 9 | cidreira
# Processing Record 40 of Set 9 | sola
# Processing Record 41 of Set 9 | trincomalee
# Processing Record 42 of Set 9 | petatlan
# Processing Record 43 of Set 9 | hay river
# Processing Record 44 of Set 9 | savonlinna
# Processing Record 45 of Set 9 | kandrian
# Processing Record 46 of Set 9 | sisimiut
# Processing Record 47 of Set 9 | san carlos
# Processing Record 48 of Set 9 | san ramon
# Processing Record 49 of Set 9 | tondano
# Processing Record 50 of Set 9 | nsanje
# Processing Record 1 of Set 10 | yingcheng
# Processing Record 2 of Set 10 | tateyama
# Processing Record 3 of Set 10 | marawi
# Processing Record 4 of Set 10 | uyaan
# Processing Record 5 of Set 10 | kuldur
# Processing Record 6 of Set 10 | swan hill
# Processing Record 7 of Set 10 | ayan
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | mackay
# Processing Record 10 of Set 10 | esperance
# Processing Record 11 of Set 10 | kamaishi
# Processing Record 12 of Set 10 | dangriga
# Processing Record 13 of Set 10 | ratnagiri
# Processing Record 14 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 15 of Set 10 | strezhevoy
# Processing Record 16 of Set 10 | havre-saint-pierre
# Processing Record 17 of Set 10 | leshukonskoye
# Processing Record 18 of Set 10 | inuvik
# Processing Record 19 of Set 10 | ponta delgada
# Processing Record 20 of Set 10 | maki
# Processing Record 21 of Set 10 | bestobe
# Processing Record 22 of Set 10 | pozo colorado
# Processing Record 23 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 25 of Set 10 | auki
# Processing Record 26 of Set 10 | nagato
# Processing Record 27 of Set 10 | tukrah
# Processing Record 28 of Set 10 | lamu
# Processing Record 29 of Set 10 | spokane
# Processing Record 30 of Set 10 | camacupa
# Processing Record 31 of Set 10 | nizhneudinsk
# Processing Record 32 of Set 10 | ballina
# Processing Record 33 of Set 10 | formosa
# Processing Record 34 of Set 10 | poquoson
# Processing Record 35 of Set 10 | norman wells
# Processing Record 36 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 10 | barcelos
# Processing Record 38 of Set 10 | gaoua
# Processing Record 39 of Set 10 | leh
# Processing Record 40 of Set 10 | gorontalo
# Processing Record 41 of Set 10 | teya
# Processing Record 42 of Set 10 | takoradi
# Processing Record 43 of Set 10 | champerico
# Processing Record 44 of Set 10 | walvis bay
# Processing Record 45 of Set 10 | vizimyary
# City not found. Skipping...
# Processing Record 46 of Set 10 | stephenville crossing
# Processing Record 47 of Set 10 | xam nua
# Processing Record 48 of Set 10 | calamar
# Processing Record 49 of Set 10 | mishkino
# Processing Record 50 of Set 10 | baturaja
# Processing Record 1 of Set 11 | labrea
# Processing Record 2 of Set 11 | smithville
# Processing Record 3 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 11 | arlit
# Processing Record 5 of Set 11 | bara
# Processing Record 6 of Set 11 | taicheng
# Processing Record 7 of Set 11 | lindi
# Processing Record 8 of Set 11 | pochutla
# Processing Record 9 of Set 11 | jumla
# Processing Record 10 of Set 11 | magadan
# Processing Record 11 of Set 11 | mandalgovi
# Processing Record 12 of Set 11 | luderitz
# Processing Record 13 of Set 11 | ereymentau
# Processing Record 14 of Set 11 | miri
# Processing Record 15 of Set 11 | high rock
# Processing Record 16 of Set 11 | coahuayana
# Processing Record 17 of Set 11 | havelock
# Processing Record 18 of Set 11 | korla
# Processing Record 19 of Set 11 | rawlins
# Processing Record 20 of Set 11 | chake chake
# Processing Record 21 of Set 11 | stornoway
# Processing Record 22 of Set 11 | bicas
# Processing Record 23 of Set 11 | villa carlos paz
# Processing Record 24 of Set 11 | bereznik
# Processing Record 25 of Set 11 | nsunga
# Processing Record 26 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 11 | mexico
# Processing Record 28 of Set 11 | spring hill
# Processing Record 29 of Set 11 | pital
# Processing Record 30 of Set 11 | tokat
# Processing Record 31 of Set 11 | chernyshevskiy
# Processing Record 32 of Set 11 | haines junction
# Processing Record 33 of Set 11 | hosbach
# Processing Record 34 of Set 11 | srednekolymsk
# Processing Record 35 of Set 11 | bom jesus
# Processing Record 36 of Set 11 | hakkari
# Processing Record 37 of Set 11 | rio grande
# Processing Record 38 of Set 11 | samsun
# Processing Record 39 of Set 11 | cooma
# Processing Record 40 of Set 11 | pangabuan
# Processing Record 41 of Set 11 | jalna
# Processing Record 42 of Set 11 | padang
# Processing Record 43 of Set 11 | ust-koksa
# Processing Record 44 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 11 | hailin
# Processing Record 46 of Set 11 | cockburn town
# Processing Record 47 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 48 of Set 11 | tromso
# Processing Record 49 of Set 11 | erzin
# Processing Record 50 of Set 11 | poopo
# Processing Record 1 of Set 12 | cayenne
# Processing Record 2 of Set 12 | carolina
# Processing Record 3 of Set 12 | shakiso
# Processing Record 4 of Set 12 | tilbury
# Processing Record 5 of Set 12 | toora-khem
# Processing Record 6 of Set 12 | artvin
# Processing Record 7 of Set 12 | bambanglipuro
# Processing Record 8 of Set 12 | ola
# Processing Record 9 of Set 12 | yerbogachen
# Processing Record 10 of Set 12 | gat
# Processing Record 11 of Set 12 | chumikan
# Processing Record 12 of Set 12 | sahuaripa
# Processing Record 13 of Set 12 | rocha
# Processing Record 14 of Set 12 | mwinilunga
# Processing Record 15 of Set 12 | riaba
# City not found. Skipping...
# Processing Record 16 of Set 12 | dharchula
# Processing Record 17 of Set 12 | ntungamo
# Processing Record 18 of Set 12 | kungurtug
# Processing Record 19 of Set 12 | ndjole
# Processing Record 20 of Set 12 | harbour breton
# Processing Record 21 of Set 12 | esmeraldas
# Processing Record 22 of Set 12 | codrington
# Processing Record 23 of Set 12 | murom
# Processing Record 24 of Set 12 | dondo
# Processing Record 25 of Set 12 | margate
# Processing Record 26 of Set 12 | iquitos
# Processing Record 27 of Set 12 | idenao
# Processing Record 28 of Set 12 | vao
# Processing Record 29 of Set 12 | kattivakkam
# Processing Record 30 of Set 12 | krasnoselkup
# Processing Record 31 of Set 12 | sukhumi
# Processing Record 32 of Set 12 | cah ab
# City not found. Skipping...
# Processing Record 33 of Set 12 | fresnillo
# Processing Record 34 of Set 12 | westport
# Processing Record 35 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 36 of Set 12 | chit baragaon
# City not found. Skipping...
# Processing Record 37 of Set 12 | iranshahr
# Processing Record 38 of Set 12 | florianopolis
# Processing Record 39 of Set 12 | yablonovo
# Processing Record 40 of Set 12 | bathsheba
# Processing Record 41 of Set 12 | vredendal
# Processing Record 42 of Set 12 | vokhma
# Processing Record 43 of Set 12 | hailar
# Processing Record 44 of Set 12 | ipixuna
# Processing Record 45 of Set 12 | cabedelo
# Processing Record 46 of Set 12 | smoky lake
# Processing Record 47 of Set 12 | ambon
# Processing Record 48 of Set 12 | sungaipenuh
# Processing Record 49 of Set 12 | krasnaya zarya
# Processing Record 50 of Set 12 | maltahohe
# Processing Record 1 of Set 13 | chicama
# Processing Record 2 of Set 13 | kharagpur
# Processing Record 3 of Set 13 | quang ngai
# Processing Record 4 of Set 13 | berlevag
# Processing Record 5 of Set 13 | yara
# Processing Record 6 of Set 13 | beisfjord
# Processing Record 7 of Set 13 | rizhao
# Processing Record 8 of Set 13 | lubango
# Processing Record 9 of Set 13 | spornoye
# Processing Record 10 of Set 13 | mantua
# Processing Record 11 of Set 13 | araripina
# Processing Record 12 of Set 13 | kailua
# Processing Record 13 of Set 13 | quatre cocos
# Processing Record 14 of Set 13 | cururupu
# Processing Record 15 of Set 13 | ngunguru
# Processing Record 16 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 17 of Set 13 | oranjemund
# Processing Record 18 of Set 13 | zyryanka
# Processing Record 19 of Set 13 | jiujiang
# Processing Record 20 of Set 13 | mainz
# Processing Record 21 of Set 13 | halifax
# Processing Record 22 of Set 13 | neuquen
# Processing Record 23 of Set 13 | gerardmer
# Processing Record 24 of Set 13 | arcos
# Processing Record 25 of Set 13 | north bend
# Processing Record 26 of Set 13 | raudeberg
# Processing Record 27 of Set 13 | togitsu
# Processing Record 28 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 13 | cervo
# Processing Record 30 of Set 13 | verkhnyaya inta
# Processing Record 31 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 13 | gafanha da encarnacao
# Processing Record 33 of Set 13 | santa cruz del norte
# Processing Record 34 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 35 of Set 13 | tura
# Processing Record 36 of Set 13 | straumen
# Processing Record 37 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 13 | viedma
# Processing Record 39 of Set 13 | caraballeda
# Processing Record 40 of Set 13 | thai binh
# Processing Record 41 of Set 13 | torbat-e jam
# Processing Record 42 of Set 13 | ardabil
# Processing Record 43 of Set 13 | huanren
# Processing Record 44 of Set 13 | kirksville
# Processing Record 45 of Set 13 | kalmunai
# Processing Record 46 of Set 13 | soria
# Processing Record 47 of Set 13 | fare
# Processing Record 48 of Set 13 | weligama
# Processing Record 49 of Set 13 | saint-francois
# Processing Record 50 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 14 | saint anthony
# Processing Record 2 of Set 14 | ruteng
# Processing Record 3 of Set 14 | santa maria
# Processing Record 4 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 14 | kulhudhuffushi
# Processing Record 6 of Set 14 | ystad
# Processing Record 7 of Set 14 | cape coast
# Processing Record 8 of Set 14 | burayevo
# Processing Record 9 of Set 14 | vammala
# Processing Record 10 of Set 14 | boyolangu
# Processing Record 11 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 14 | sorland
# Processing Record 13 of Set 14 | vila franca do campo
# Processing Record 14 of Set 14 | kampong chhnang
# Processing Record 15 of Set 14 | yatou
# Processing Record 16 of Set 14 | ambulu
# Processing Record 17 of Set 14 | manicore
# Processing Record 18 of Set 14 | santa cruz
# Processing Record 19 of Set 14 | santa marinella
# Processing Record 20 of Set 14 | gazli
# Processing Record 21 of Set 14 | naze
# Processing Record 22 of Set 14 | porto santo
# Processing Record 23 of Set 14 | camacha
# Processing Record 24 of Set 14 | amapa
# Processing Record 25 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 14 | yarada
# Processing Record 27 of Set 14 | kintampo
# Processing Record 28 of Set 14 | springbok
# Processing Record 29 of Set 14 | hualmay
# Processing Record 30 of Set 14 | andros town
# Processing Record 31 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 14 | ovsyanka
# Processing Record 33 of Set 14 | pali
# Processing Record 34 of Set 14 | carikar
# City not found. Skipping...
# Processing Record 35 of Set 14 | adre
# Processing Record 36 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 37 of Set 14 | baykit
# Processing Record 38 of Set 14 | talara
# Processing Record 39 of Set 14 | faya
# Processing Record 40 of Set 14 | te anau
# Processing Record 41 of Set 14 | kirakira
# Processing Record 42 of Set 14 | tangjiazhuang
# Processing Record 43 of Set 14 | udachnyy
# Processing Record 44 of Set 14 | genteng
# Processing Record 45 of Set 14 | mbarara
# Processing Record 46 of Set 14 | bogale
# Processing Record 47 of Set 14 | fort-shevchenko
# Processing Record 48 of Set 14 | sao caetano de odivelas
# Processing Record 49 of Set 14 | ternate
# Processing Record 50 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 15 | sovetskiy
# Processing Record 2 of Set 15 | zhanaozen
# Processing Record 3 of Set 15 | le port
# Processing Record 4 of Set 15 | wilkie
# Processing Record 5 of Set 15 | prescott valley
# Processing Record 6 of Set 15 | nakhon thai
# Processing Record 7 of Set 15 | hoi an
# Processing Record 8 of Set 15 | tanete
# Processing Record 9 of Set 15 | port hedland
# Processing Record 10 of Set 15 | remedios
# Processing Record 11 of Set 15 | abay
# Processing Record 12 of Set 15 | valdivia
# Processing Record 13 of Set 15 | drayton valley
# Processing Record 14 of Set 15 | sanghar
# Processing Record 15 of Set 15 | hambantota
# Processing Record 16 of Set 15 | goshen
# Processing Record 17 of Set 15 | xichang
# Processing Record 18 of Set 15 | tunapuna
# Processing Record 19 of Set 15 | shahr-e babak
# Processing Record 20 of Set 15 | vagur
# Processing Record 21 of Set 15 | shieli
# Processing Record 22 of Set 15 | arman
# Processing Record 23 of Set 15 | macusani
# Processing Record 24 of Set 15 | warri
# Processing Record 25 of Set 15 | kisii
# Processing Record 26 of Set 15 | zaraysk
# Processing Record 27 of Set 15 | susangerd
# Processing Record 28 of Set 15 | broome
# Processing Record 29 of Set 15 | itatiaia
# Processing Record 30 of Set 15 | nouadhibou
# Processing Record 31 of Set 15 | roma
# Processing Record 32 of Set 15 | coihaique
# Processing Record 33 of Set 15 | darhan
# Processing Record 34 of Set 15 | smithers
# Processing Record 35 of Set 15 | sesheke
# Processing Record 36 of Set 15 | sistranda
# Processing Record 37 of Set 15 | klyuchi
# Processing Record 38 of Set 15 | libenge
# Processing Record 39 of Set 15 | batemans bay
# Processing Record 40 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 15 | chagoda
# Processing Record 43 of Set 15 | plainview
# Processing Record 44 of Set 15 | nyurba
# Processing Record 45 of Set 15 | tazovskiy
# Processing Record 46 of Set 15 | bac lieu
# Processing Record 47 of Set 15 | ossora
# Processing Record 48 of Set 15 | bage
# Processing Record 49 of Set 15 | kimbe
# Processing Record 50 of Set 15 | matadi
# Processing Record 1 of Set 16 | juegang
# Processing Record 2 of Set 16 | burica
# City not found. Skipping...
# Processing Record 3 of Set 16 | hokitika
# Processing Record 4 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 16 | myaundzha
# Processing Record 6 of Set 16 | celestun
# Processing Record 7 of Set 16 | lerwick
# Processing Record 8 of Set 16 | meulaboh
# Processing Record 9 of Set 16 | longyan
# Processing Record 10 of Set 16 | vrede
# Processing Record 11 of Set 16 | yuksekova
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Muana      BR  -1.5283  -49.2167     88.83        54          86
# 1   Punta Arenas      CL -53.1500  -70.9167     42.91        61          75
# 2        Kwinana      AU -32.2500  115.7667     54.23        95          66
# 3        Rikitea      PF -23.1203 -134.9692     70.99        62          67
# 4      Mahebourg      MU -20.4081   57.7000     70.25        83          75
# 5        Ushuaia      AR -54.8000  -68.3000     40.66        81          75
# 6        Trapani      IT  37.8333   12.6667     88.90        66           0
# 7          Yumen      CN  40.2833   97.2000     78.01        40         100
# 8  Mar Del Plata      AR -38.0023  -57.5575     53.94        64          40
# 9   Saint-Pierre      RE -21.3393   55.4781     67.68        77           0
#
#    Wind Speed Current Description
# 0        2.93     overcast clouds
# 1        4.61       broken clouds
# 2        1.99       broken clouds
# 3       21.12       broken clouds
# 4       11.50       broken clouds
# 5       12.66          light rain
# 6       13.80           clear sky
# 7       10.85     overcast clouds
# 8        9.22    scattered clouds
# 9        4.61           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_weather_df.to_csv(output_data_file, index_label="City_ID")
